# %%
import sys
sys.path.append('C:\\Users\\jholt\\Git\\GCOMS1k\\STARTFILES\\Generate_Domains\\Python')
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import gcoms1k

# %%
bathyname="C:/Users/jholt/OneDrive - NOC/Documents/Projects/ACCORD/GEBCO_2014/GEBCO_2014_2D.nc"

# %%
a=gcoms1k.gcoms1k(bathyname)
# Out:
# C:/Users/jholt/OneDrive - NOC/Documents/Projects/ACCORD/GEBCO_2014/GEBCO_2014_2D.nc

# %%
limits=[40,60,-12,12]
a.basin(limits,10)
# Out:
# [40, 60, -12, 12]
# (2400, 2880)
# (240, 288)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 a.bathymetry
#
# AttributeError: 'gcoms1k' object has no attribute 'bathymetry'

# %%
plt.pcolormesh(a.basin_bathy.bathymetry[:,:])

# %%
lat_min=-20.
lat_max=-15.
lon_min=-10
lon_max=0
jmin=np.argmin((f.lat.values-lat_min)**2)
jmax=np.argmin((f.lat.values-lat_max)**2)
imin=np.argmin((f.lon.values-lon_min)**2)
imax=np.argmin((f.lon.values-lon_max)**2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       3 lon_min=-10
#       4 lon_max=0
# ----> 5 jmin=np.argmin((f.lat.values-lat_min)**2)
#       6 jmax=np.argmin((f.lat.values-lat_max)**2)
#       7 imin=np.argmin((f.lon.values-lon_min)**2)
#
# NameError: name 'f' is not defined

# %%
imin,imax,jmin,jmax

# %%
f=f.isel(lat=range(imin,imax))

# %%
f
