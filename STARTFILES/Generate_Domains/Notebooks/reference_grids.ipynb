# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# %%
bathyname="C:/Users/jholt/OneDrive - NOC/Documents/Projects/ACCORD/GEBCO_2014/GEBCO_2014_2D.nc"

# %%
f=xr.open_dataset(bathyname)

# %%
f
# Out:
# <xarray.Dataset>
# Dimensions:    (lat: 21600, lon: 43200)
# Coordinates:
#   * lat        (lat) float64 -90.0 -89.99 -89.98 -89.97 ... 89.98 89.99 90.0
#   * lon        (lon) float64 -180.0 -180.0 -180.0 -180.0 ... 180.0 180.0 180.0
# Data variables:
#     elevation  (lat, lon) float64 ...
# Attributes:
#     Conventions:  CF-1.6
#     title:        The GEBCO_2014 Grid - a continuous terrain model for oceans...
#     institution:  On behalf of the General Bathymetric Chart of the Oceans (G...
#     source:       The bathymetric portion of the GEBCO_2014 Grid was largely ...
#     history:      This is version 20150318 of the data set. Information on th...
#     references:   Information on the data set is available from the GEBCO pro...
#     comment:      The data in the GEBCO_2014 Grid should not be used for navi...
#     node_offset:  1

# %%
lat_min=-20.
lat_max=-15.
lon_min=-10
lon_max=0
jmin=np.argmin((f.lat.values-lat_min)**2)
jmax=np.argmin((f.lat.values-lat_max)**2)
imin=np.argmin((f.lon.values-lon_min)**2)
imax=np.argmin((f.lon.values-lon_max)**2)

# %%
imin,imax,jmin,jmax
# Out:
# (20399, 21599, 0, 599)

# %%
f=f.isel(lat=range(imin,imax))

# %%
f
# Out:
# <xarray.Dataset>
# Dimensions:    (lat: 600, lon: 43200)
# Coordinates:
#   * lat        (lat) float64 -20.0 -20.0 -19.99 -19.98 ... -15.03 -15.02 -15.01
#   * lon        (lon) float64 -180.0 -180.0 -180.0 -180.0 ... 180.0 180.0 180.0
# Data variables:
#     elevation  (lat, lon) float64 ...
# Attributes:
#     Conventions:  CF-1.6
#     title:        The GEBCO_2014 Grid - a continuous terrain model for oceans...
#     institution:  On behalf of the General Bathymetric Chart of the Oceans (G...
#     source:       The bathymetric portion of the GEBCO_2014 Grid was largely ...
#     history:      This is version 20150318 of the data set. Information on th...
#     references:   Information on the data set is available from the GEBCO pro...
#     comment:      The data in the GEBCO_2014 Grid should not be used for navi...
#     node_offset:  1
